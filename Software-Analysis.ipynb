# %% [markdown]
# # Schwachstellenanalyse hinsichtlich bekannter CVE's

# %% [markdown]
# ## Fragestellung
#
# Treten in dem vorliegendem Git-Projekt mögliche Sicherheitslücken aufgrund von veralteten/fehlerhaften Bibliotheken & Frameworks auf? Wie kritisch werden jene Schwachstellen eingeschätzt?
#
# ### Relevanz
# * historische Systeme tendieren zu veralteten Versionen von Bibliotheken/Frameworks/Artefakten --> kritisch bzgl. Erhalt von qualitativen Softwareeigenschaften, Schutzzielen der Informationssicherheit (und beispielsweise auch Zertifizierung im Unternehmensumfeld)
# * relevant für Kunden/Anwender und Provider/Entwickler zugleich --> Ausnutzung von Schwachstellen um Angriffe wie Sniffer-Angriffe, Denial-of-Service oder auch Buffer-Overflows zu erzeugen
# * Konsequenz kann z.B. Datenverluste, unautorisierter Datenzugriff, Vertrauensverlust sein
# * regelmäßige Checks und Updates reduzieren Aufwände im Gegenzug zu Updates, welche mehrere Versionen überspringen
# * Verkaufsargument in mancher Branche
#
# ### mögliche Konsequenzen
# Dienstleister:
# * weitereführende Analyse und Risikobewertung möglich: Welche Artefakte sind für uns relevant? Welche müssen inwieweit priorisiert werden? Wann kann ein Update eingeplannt werden? Wann ist die letzte Deadline? Welche Handlungsaktionen müssen fehlenden Bugfixes getätigt werden?
# * Erstellung einer Aufwandsschätzung bzgl. Entwicklung, Updatemigration, Test, Integration, Auslieferung & möglich Inkludierung in das nächste Release oder Light-Release/Bugfix/Snapshot
#
# Kunden:
# * Möglichkeit Druck für Handlungsbedarf beim Dienstleister auszuüben
# * Worst-Case: Möglichkeit über Anbieterwechsel nachzudenken

# %% [markdown]
# ## Datenquelle
# * Java-Strukturen eines Git-Projekts, welches aufgrund der Anpassung der POM.xml durch jQAssistant gescannt und in einer Neo4j-Instanz gespeichert wurde
# * Daten zu CVE's über Dateiimport und Request an die cveapi (letzteres nur über einen übersichtlichen Datensatz möglich, da die Firewall des API-Servers den Request (zum Schutz vor Denial-of-Service-Attacken) sperrt
#
# ### konkrete Quellen
# * Projekt: Petclinic --> verwendete Frameworks & zugehörige Versionen
# * CVE-Dateiimport: historische CVE's von 2020 als JSON-Datei (Weiterhin auch 2019 und bisherige CVE's von 2021(Stand: 23.08.2021))
# * cve-api: Import der 20 aktuellsten CVE's
#
# ### mögliche Schwachstellen
# * Artefakte/Frameworks ohne Versionsnummer, Versionsnummer mit unbrauchbaren Präfix/Suffix ("Verunreinheiten")
# * Artefakte/Frameworks, welche nicht über jQAssistant erfasst werden konnten
# * genaues Matching zwischen verwendete Version und schwachstellenrelevante Version

# %% [markdown]
# ### Infos CVE
# CVE = Common Vulnerabilities and Exposures
# * Industriestandard zur Benennung öffentlich bekannter Sicherheitslücken
# * gewissen Druck auf die Hersteller der betroffenen Produkte aufgrund öffentlicher Schwachstellen
# * in großen Teilen ein Community-Projekt --> MITRE Organization als Head of

# %% [markdown]
# ## Annahmen
# * Die relevanten Artefakte konnten von jQAssistant gescannt werden und als Artefakte mit den entsprechenden Labels "name" und "version" gespeichert werden.
# * Relevante Daten wie betroffene Konfigurationen, Versionen und Schweregrad der Schwachstelle können über die JSON-Strukturierung der CVE's abgerufen werden.
# * Die Artefakte können mit den Informationen der CVE's abgeglichen werden.

# %% [markdown]
# ## Validierung
#
# ### Datenaufbereitung
# * Tabellenansicht bzgl. aller relevanten (im Projekt möglichen) Schwachstellen
# * Graphische Übersicht über betroffene Artefakte und Anzahl der zugehörigen CVE's
# * Graphische Übersicht über Impact Score der auftretenden CVE's
# * Graphische Übersicht über Exploitability Score der auftretenden CVE's
#
# ### Aktionen
# * Review bzgl. der auftretenden Schwachstellen und dessen Schweregrade
# * Validierung & Evaluierung der Schwachstellen durch Domainexperten
# * Planung der nächsten Schritte/Meilensteine durch Projekt

# %% [markdown]
# ## Implementierung
# * Identifikation der relevanten Artefakte über Node Label "Artifact" --> Extraction des Namens & der Version
# * weitere mögliche Artefakte können über die Property-Nodes des Nodes der POM.xml mit der Relationship [:HAS_PROPERTY] identifiziert werden --> Extraction von Name & Version auch hier möglich
# * Merging beider DataFrames um eine vollständige Liste zu erhalten & ggf. Versionsangabe von störenden Anhängen befreien
# * Extraction der CVE's aus der JSON-Datei --> Auflösung von Verschachtelungen und Kürzung der Spaltenanzahl
# * Abgleich der identifizierten Artefakte aus dem Projekt mit den betroffenden Konfiguration aus den CVE's
# * resultierendes DataFrame kann als Excel gespeichert & für Visualisierungen genutzt werden

# %%
#Import of all used libraries
import py2neo
import pandas as pd
import numpy as np

import json
from pandas.io.json import json_normalize
#import openpyxl

import urllib3
from urllib3 import request
import json
import certifi

from IPython.display import display, HTML
import pygal

# %%
from IPython.display import display, HTML

base_html = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

# %%
#Verbindung zu neo4j und Speicherung des Graphen in der Variable 'Graph'

graph = py2neo.Graph('http://neo4j:neo@localhost:7406/db/data')

# %%
#Query um alle Artefakte bzgl. Frameworks zu erhalten
#Bereininung von Duplikaten, Testfiles und unnötigen Präfixes 

query = """
MATCH (artifact:Artifact) WHERE NOT artifact.name contains 'petclinic' AND NOT artifact.type = 'test-jar'
WITH DISTINCT artifact 
Return artifact.name as Artefakt, artifact.version as Version
"""
df_usedArtifacts = pd.DataFrame(graph.run(query), columns=['Artefakt', 'Version'])
df_usedArtifacts['Version'] = df_usedArtifacts['Version'].str.replace('[.-]?[a-zA-Z]+[-]?\w+([.-]?\d*)*$','',regex=True)
df_usedArtifacts
# Out:
#                                               Artefakt Version
# 0                          spring-boot-starter-logging   2.1.0
# 1                                  spring-boot-starter   2.1.0
# 2                                 javax.annotation-api   1.3.2
# 3                                          spring-core   5.1.2
# 4                                            snakeyaml    1.23
# ..                                                 ...     ...
# 929  infinispan-protocol-parser-generator-maven-plugin   9.4.0
# 930                               git-commit-id-plugin   2.2.5
# 931                                  lifecycle-mapping   1.0.0
# 932                                jacoco-maven-plugin   0.8.2
# 933                                 wro4j-maven-plugin   1.8.0
#
# [934 rows x 2 columns]

# %%
#Query zu allen Frameworks, die als Property an der pom.xml gespeichert sind
#Joining beider Dataframes, Duplikaterntfernung

query2 = """
Match (p:Pom)-[:HAS_PROPERTY]->(pr:Property) 
Return pr.name as Artefakt, pr.value as Version
"""
df_PomProperties = pd.DataFrame(graph.run(query2), columns=['Artefakt', 'Version'])
df_PomProperties['Artefakt'] = df_PomProperties['Artefakt'].str.replace('.version','',regex=True)

df_usedItems = pd.merge(left=df_usedArtifacts, right=df_PomProperties, how='outer', left_on='Artefakt', right_on='Artefakt')
df_usedItems = df_usedItems.drop_duplicates(subset='Artefakt', keep="first")
df_usedItems = df_usedItems.reset_index()
df_usedItems = df_usedItems.drop(['index'], axis=1)
for i in df_usedItems.index:
    version_y = df_usedItems['Version_y'][i]
    version_x = df_usedItems['Version_x'][i]
    if pd.isnull(version_x) and (version_y is not None):
        df_usedItems.loc[i, 'Version_x'] = version_y

df_usedItems = df_usedItems.drop(['Version_y'], axis=1)
df_usedItems.columns =['Artefakt', 'Version']
df_usedItems
# Out:
#                         Artefakt Version
# 0    spring-boot-starter-logging   2.1.0
# 1            spring-boot-starter   2.1.0
# 2           javax.annotation-api   1.3.2
# 3                    spring-core   5.1.2
# 4                      snakeyaml    1.23
# ..                           ...     ...
# 981                  javax-jaxws   2.3.1
# 982       prometheus-pushgateway   0.5.0
# 983                      mariadb   2.3.0
# 984                      rxjava2   2.2.3
# 985                      mongodb   3.8.2
#
# [986 rows x 2 columns]

# %% [markdown]
# # Datenimport über Circl-API

# %%
http = urllib3.PoolManager(
    cert_reqs="CERT_REQUIRED",
    ca_certs=certifi.where()
)


url ='https://cve.circl.lu/api/cve/CVE-2020-24616'
#url ='https://cve.circl.lu/api/last' #Import der 30 aktuellsten CVE's
r = http.request('GET', url)
r.status

# JSON-Daten werden ausgewertet & in ein Dictionary gespeichert
data = json.loads(r.data.decode('utf-8'))
#data

# Entschachtlung der JSON in ein DataFrame
df_circl = pd.json_normalize(data)
df_circl

# %%
#Datenaufbereitung

#Liste mit true & false-Werten entsprechend der ausgewählten Spalten
cList= df_circl.columns.isin(['id', 'summary', 'impact.availability', 'impact.confidentiality', 'impact.integrity'])

#DataFrame mit ausgewählten Zeilen und Spalten
df_circl = df_circl.loc[:,cList]
df_circl.columns =['ID', 'Summary', 'Availability impact', 'Confidentiality impact', 'Integrity impact']

df_vulnerabilities = pd.json_normalize(data, record_path='vulnerable_product', meta=['summary'])
df_vulnerabilities.columns =['Vulnerable product', 'Summary']
df_vulnerabilities = df_vulnerabilities.loc[:,df_vulnerabilities.columns.isin(['Vulnerable product', 'Summary'])]

#Joining der beiden DataFrames
mergedList = pd.merge(left=df_circl, right=df_vulnerabilities, left_on='Summary', right_on='Summary')
mergedList

# %%
#Scanning the List for used frameworks and versions
#Loop with result in new Dictionary (because we need Key-Values)

terms = []

for j in df_usedItems.index:
    #print('Check of this Framework:'+ df_usedItems['Framework'][j])
    version = df_usedItems['Version'][j]
    framework = df_usedItems['Artefakt'][j]
    if version is not None:
        term = '(' + framework + '[^a-zA-Z_0-9]+' + version + ')'
        terms.append(term)
    else:
        terms.append('('+framework+')')
terms

mergedList[(mergedList['Vulnerable product'].str.contains('|'.join(terms)))]

# %% [markdown]
# # Datenimport über cveapi oder entsprechender json
# Beide besitzen eine ähnliche Datenstrukturierung. Der Request über die cveapi erweitert die Strukturierung nur um wenige weitere Key-Value-Paare, weshalb das DataFrame zusätzlicher Anpassung benötigt.

# %%
# Laden der statischen CVE-Daten über JSON-Datei
# Download über https://nvd.nist.gov/vuln/data-feeds

api = 'false'

with open('CVE/nvdcve-1.1-2020.json', encoding='utf-8') as staticData:
    jsonData = json.load(staticData)
df_raw = pd.json_normalize(jsonData, record_path =['CVE_Items'])

# %%
# Datenimport über cveapi 
# Import aller CVE's wird nicht empfohlen, da dies von der Firewall 
# zur Prävention von Denial-of-service-Attacken verhindert wird

api = 'true'

http = urllib3.PoolManager(
    cert_reqs="CERT_REQUIRED",
    ca_certs=certifi.where()
)

#Request einer spezifischen CVE
#url ='https://services.nvd.nist.gov/rest/json/cves/1.0?CVE-2020-24616'

#Request der 20 aktuellsten CVE
url ='https://services.nvd.nist.gov/rest/json/cves/1.0?startIndex=20' 

#Request der CVE ab einem definierten Startzeitpunkt
#url ='https://services.nvd.nist.gov/rest/json/cves/1.0?modStartDate=2021-01-0101T00:00:00:000 UTC-05:00


r = http.request('GET', url)
r.status

# JSON-Daten werden ausgewertet & in ein Dictionary gespeichert
jsonData = json.loads(r.data.decode('utf-8'))
df_nested_list = pd.json_normalize(jsonData)
df_raw = df_nested_list.loc[:,df_nested_list.columns.isin(['result.CVE_Items'])]
json_struct = json.loads(df_raw.to_json(orient="records")) 
df_raw = pd.json_normalize(json_struct,record_path =['result.CVE_Items'])

# %%
#Aufbereitung der Daten zu einer Tabelle mit ID, Beschreibung & Schweregrad der Sicherheitslücke

#DataFrame wird auf 6 Spalten gekürzt & Spalten werden umbenannt (Lesbarkeit)
vulnerableList= df_raw.columns.isin(['cve.CVE_data_meta.ID', 'impact.baseMetricV3.cvssV3.confidentialityImpact', 'impact.baseMetricV3.cvssV3.integrityImpact', 'impact.baseMetricV3.cvssV3.availabilityImpact', 'impact.baseMetricV3.exploitabilityScore', 'impact.baseMetricV3.impactScore'])
df_basic = df_raw.loc[:,vulnerableList]
df_basic.columns =['CVE-ID', 'Confidentially Impact', 'Integrity Impact', 'Availability Impact', 'Exploitability Score', 'Impact Score']


#Neues DF mit den CVE-Beschreibungen, da "cve.description.description_data" ein Dictionary enthält
df_raw2 = df_raw.loc[:,df_raw.columns.isin(['cve.CVE_data_meta.ID', 'cve.description.description_data'])]

#Reload & Manipulation des DataFrames um an die entsprechende Beschreibung zu gelangen
json_struct = json.loads(df_raw2.to_json(orient="records")) 
df_desc = pd.json_normalize(json_struct,record_path =['cve.description.description_data'], meta=['cve.CVE_data_meta.ID'])
df_desc = df_desc.loc[:,df_desc.columns.isin(['value', 'cve.CVE_data_meta.ID'])]
df_desc.columns =['CVE description', 'CVE-ID']

#DF-Join von df_basic & df_desc
basicList = pd.merge(left=df_basic, right=df_desc, left_on='CVE-ID', right_on='CVE-ID')
basicList = basicList[['CVE-ID', 'CVE description', 'Confidentially Impact', 'Integrity Impact', 'Availability Impact', 'Impact Score', 'Exploitability Score']]
basicList
# Out:
#               CVE-ID                                    CVE description  \
# 0      CVE-2020-0001  In getProcessRecordLocked of ActivityManagerSe...
# 1      CVE-2020-0002  In ih264d_init_decoder of ih264d_api.c, there ...
# 2      CVE-2020-0003  In onCreate of InstallStart.java, there is a p...
# 3      CVE-2020-0004  In generateCrop of WallpaperManagerService.jav...
# 4      CVE-2020-0005  In btm_read_remote_ext_features_complete of bt...
# ...              ...                                                ...
# 18017  CVE-2020-9994  A path handling issue was addressed with impro...
# 18018  CVE-2020-9995  An issue existed in the parsing of URLs. This ...
# 18019  CVE-2020-9996  A use after free issue was addressed with impr...
# 18020  CVE-2020-9997  An information disclosure issue was addressed ...
# 18021  CVE-2020-9999  A memory corruption issue was addressed with i...
#
#       Confidentially Impact Integrity Impact Availability Impact  \
# 0                      HIGH             HIGH                HIGH
# 1                      HIGH             HIGH                HIGH
# 2                      HIGH             HIGH                HIGH
# 3                      NONE             NONE                HIGH
# 4                      HIGH             HIGH                HIGH
# ...                     ...              ...                 ...
# 18017                  NONE             HIGH                HIGH
# 18018                   LOW              LOW                NONE
# 18019                  HIGH             HIGH                HIGH
# 18020                  HIGH             NONE                NONE
# 18021                  HIGH             HIGH                HIGH
#
#        Impact Score  Exploitability Score
# 0               5.9                   1.8
# 1               5.9                   2.8
# 2               5.9                   0.8
# 3               3.6                   1.8
# 4               5.9                   0.8
# ...             ...                   ...
# 18017           5.2                   1.8
# 18018           2.7                   2.8
# 18019           5.9                   1.8
# 18020           3.6                   1.8
# 18021           5.9                   1.8
#
# [18022 rows x 7 columns]

# %%
#Neues DF mit den Konfigurationsbeschreibungen, da "configurations.nodes" ein Dictionary enthält
newList= df_raw.columns.isin(['cve.CVE_data_meta.ID', 'configurations.nodes'])
df_raw3 = df_raw.loc[:,newList]

#Reload & Manipulation des DataFrames um an die entsprechende fehlerhafte Konfiguration zu gelangen
json_struct = json.loads(df_raw3.to_json(orient="records")) 
df_conf = pd.json_normalize(json_struct,record_path =['configurations.nodes'], meta=['cve.CVE_data_meta.ID'])
json_struct = json.loads(df_conf.to_json(orient="records")) 
df_conf2 = pd.json_normalize(json_struct,record_path =['cpe_match'], meta=['operator', 'cve.CVE_data_meta.ID'])

#Kürzung & Umbenennung der Spalten
if api == 'false':
    df_conf2 = df_conf2.loc[:,df_conf2.columns.isin(['vulnerable', 'cpe23Uri', 'versionEndIncluding', 'versionEndExcluding', 'versionStartIncluding', 'versionStartExcluding', 'operator', 'cve.CVE_data_meta.ID'])]
    df_conf2.columns =['Vulnerable for system?', 'cpe23URI', 'Last version (excl)', 'First version (incl)', 'Last version (incl)', 'First version (excl)', 'Connector/Relation', 'CVE-ID']
    df_conf2 = df_conf2[['CVE-ID', 'Vulnerable for system?', 'Connector/Relation', 'cpe23URI','First version (excl)', 'First version (incl)', 'Last version (excl)', 'Last version (incl)']]
elif api == 'true':
    df_conf2 = df_conf2.rename(columns={"cve.CVE_data_meta.ID": "CVE-ID", "vulnerable": "Vulnerable for system", "cpe23Uri": "cpe23URI", "operator": "Connector/Relation"})
    df_conf2 = df_conf2.drop(columns=['cpe_name'])
    

df_conf2
# Out:
#               CVE-ID  Vulnerable for system? Connector/Relation  \
# 0      CVE-2020-0001                    True                 OR
# 1      CVE-2020-0001                    True                 OR
# 2      CVE-2020-0001                    True                 OR
# 3      CVE-2020-0001                    True                 OR
# 4      CVE-2020-0002                    True                 OR
# ...              ...                     ...                ...
# 91092  CVE-2020-9999                    True                 OR
# 91093  CVE-2020-9999                    True                 OR
# 91094  CVE-2020-9999                    True                 OR
# 91095  CVE-2020-9999                    True                 OR
# 91096  CVE-2020-9999                    True                 OR
#
#                                           cpe23URI First version (excl)  \
# 0       cpe:2.3:o:google:android:8.0:*:*:*:*:*:*:*                  NaN
# 1       cpe:2.3:o:google:android:8.1:*:*:*:*:*:*:*                  NaN
# 2       cpe:2.3:o:google:android:9.0:*:*:*:*:*:*:*                  NaN
# 3      cpe:2.3:o:google:android:10.0:*:*:*:*:*:*:*                  NaN
# 4       cpe:2.3:o:google:android:8.0:*:*:*:*:*:*:*                  NaN
# ...                                            ...                  ...
# 91092       cpe:2.3:o:apple:ipados:*:*:*:*:*:*:*:*                  NaN
# 91093    cpe:2.3:o:apple:iphone_os:*:*:*:*:*:*:*:*                  NaN
# 91094     cpe:2.3:o:apple:mac_os_x:*:*:*:*:*:*:*:*                  NaN
# 91095         cpe:2.3:o:apple:tvos:*:*:*:*:*:*:*:*                  NaN
# 91096      cpe:2.3:o:apple:watchos:*:*:*:*:*:*:*:*                  NaN
#
#       First version (incl) Last version (excl) Last version (incl)
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 91092                  NaN                14.0                 NaN
# 91093                  NaN                14.0                 NaN
# 91094                  NaN              11.0.1                 NaN
# 91095                  NaN                14.0                 NaN
# 91096                  NaN                 7.0                 NaN
#
# [91097 rows x 8 columns]

# %%
#DataFrame bzgl. Konfigurationen mit Schwachstellen mit den verwendeten Artefakten scannen
hilfsliste1 = []
hilfsliste2 = []
df_result = df_conf2[0:0]
df_result.insert(len(df_result.columns), "verwendetes Artefakt", [])
df_result.insert(len(df_result.columns), "verwendete Version", [])

for j in df_usedItems.index:
    version = df_usedItems['Version'][j]
    artefakt = df_usedItems['Artefakt'][j]
    
    df_search = df_conf2.loc[df_conf2['cpe23URI'].str.contains(':'+artefakt + ':', case=False)]
    if df_search is not None:
        lengthDF = df_search.shape[0]
        for i in range(lengthDF):
            hilfsliste1.append(artefakt)
            hilfsliste2.append(version)
        df_search.insert(len(df_search.columns), "verwendetes Artefakt", hilfsliste1)
        df_search.insert(len(df_search.columns), "verwendete Version", hilfsliste2)
        hilfsliste1.clear()
        hilfsliste2.clear()
    df_result = df_result.append(df_search, ignore_index=True)
    
df_result
# Out:
#              CVE-ID  Vulnerable for system? Connector/Relation  \
# 0    CVE-2020-10672                    True                 OR
# 1    CVE-2020-10673                    True                 OR
# 2    CVE-2020-10673                    True                 OR
# 3    CVE-2020-10968                    True                 OR
# 4    CVE-2020-10969                    True                 OR
# ..              ...                     ...                ...
# 774   CVE-2020-7928                    True                 OR
# 775   CVE-2020-7928                    True                 OR
# 776   CVE-2020-7928                    True                 OR
# 777   CVE-2020-7929                    True                 OR
# 778   CVE-2020-7929                    True                 OR
#
#                                               cpe23URI First version (excl)  \
# 0    cpe:2.3:a:fasterxml:jackson-databind:*:*:*:*:*...                  NaN
# 1    cpe:2.3:a:fasterxml:jackson-databind:*:*:*:*:*...                  NaN
# 2    cpe:2.3:a:fasterxml:jackson-databind:*:*:*:*:*...                  NaN
# 3    cpe:2.3:a:fasterxml:jackson-databind:*:*:*:*:*...                  NaN
# 4    cpe:2.3:a:fasterxml:jackson-databind:*:*:*:*:*...                  NaN
# ..                                                 ...                  ...
# 774          cpe:2.3:a:mongodb:mongodb:*:*:*:*:*:*:*:*                  NaN
# 775          cpe:2.3:a:mongodb:mongodb:*:*:*:*:*:*:*:*                  NaN
# 776          cpe:2.3:a:mongodb:mongodb:*:*:*:*:*:*:*:*                  NaN
# 777          cpe:2.3:a:mongodb:mongodb:*:*:*:*:*:*:*:*                  NaN
# 778          cpe:2.3:a:mongodb:mongodb:*:*:*:*:*:*:*:*                  NaN
#
#     First version (incl) Last version (excl) Last version (incl)  \
# 0                  2.9.0            2.9.10.4                 NaN
# 1                  2.6.0             2.6.7.4                 NaN
# 2                  2.9.0            2.9.10.4                 NaN
# 3                  2.9.0            2.9.10.4                 NaN
# 4                  2.7.0             2.7.9.7                 NaN
# ..                   ...                 ...                 ...
# 774                4.2.0               4.2.9                 NaN
# 775                4.4.0               4.4.1                 NaN
# 776                4.5.0               4.5.1                 NaN
# 777                3.6.0              3.6.21                 NaN
# 778                4.0.0              4.0.20                 NaN
#
#     verwendetes Artefakt verwendete Version
# 0       jackson-databind              2.9.7
# 1       jackson-databind              2.9.7
# 2       jackson-databind              2.9.7
# 3       jackson-databind              2.9.7
# 4       jackson-databind              2.9.7
# ..                   ...                ...
# 774              mongodb              3.8.2
# 775              mongodb              3.8.2
# 776              mongodb              3.8.2
# 777              mongodb              3.8.2
# 778              mongodb              3.8.2
#
# [779 rows x 10 columns]

# %% [markdown]
# ### Auflistung der Schwachstellen
# Die folgende Tabelle stellt alle möglichen Schwachstellen bzgl. der verwendeten Artefakte in dem gescannten Projekt dar. Es werden neben der CVE-ID & dem Artefakt + Versionsnummer auch eine Beschreibung und die jeweiligen Scores zur Einschätzung der Relevanz und des Schweregrades aufgelistet.
# Die Liste wird als Excel abgespeichert.

# %%
#Neues DataFrame mit kompakten Daten (ohne Versionenvergleich)
df_compact = df_result[0:0]
df_compact = df_result.drop_duplicates(subset='CVE-ID', keep="first")
df_compact = df_compact.loc[:,df_compact.columns.isin(['CVE-ID', 'verwendetes Artefakt', 'verwendete Version'])]
df_compact = pd.merge(left=basicList, right=df_compact, left_on='CVE-ID', right_on='CVE-ID')
#df_compact.to_excel("result_analysis.xlsx")
df_compact
# Out:
#              CVE-ID                                    CVE description  \
# 0    CVE-2020-10672  FasterXML jackson-databind 2.x before 2.9.10.4...
# 1    CVE-2020-10673  FasterXML jackson-databind 2.x before 2.9.10.4...
# 2    CVE-2020-10683  dom4j before 2.0.3 and 2.1.x before 2.1.3 allo...
# 3    CVE-2020-10687  A flaw was discovered in all versions of Under...
# 4    CVE-2020-10705  A flaw was discovered in Undertow in versions ...
# ..              ...                                                ...
# 246   CVE-2020-8908  A temp directory creation vulnerability exists...
# 247   CVE-2020-9484  When using Apache Tomcat versions 10.0.0-M1 to...
# 248   CVE-2020-9546  FasterXML jackson-databind 2.x before 2.9.10.4...
# 249   CVE-2020-9547  FasterXML jackson-databind 2.x before 2.9.10.4...
# 250   CVE-2020-9548  FasterXML jackson-databind 2.x before 2.9.10.4...
#
#     Confidentially Impact Integrity Impact Availability Impact  Impact Score  \
# 0                    HIGH             HIGH                HIGH           5.9
# 1                    HIGH             HIGH                HIGH           5.9
# 2                    HIGH             HIGH                HIGH           5.9
# 3                     LOW              LOW                NONE           2.5
# 4                    NONE             NONE                HIGH           3.6
# ..                    ...              ...                 ...           ...
# 246                   LOW             NONE                NONE           1.4
# 247                  HIGH             HIGH                HIGH           5.9
# 248                  HIGH             HIGH                HIGH           5.9
# 249                  HIGH             HIGH                HIGH           5.9
# 250                  HIGH             HIGH                HIGH           5.9
#
#      Exploitability Score verwendetes Artefakt verwendete Version
# 0                     2.8     jackson-databind              2.9.7
# 1                     2.8     jackson-databind              2.9.7
# 2                     3.9                dom4j              2.1.1
# 3                     2.2             undertow       2.0.14.Final
# 4                     3.9             undertow       2.0.14.Final
# ..                    ...                  ...                ...
# 246                   1.8                guava              2.6.2
# 247                   1.0               tomcat             9.0.12
# 248                   3.9     jackson-databind              2.9.7
# 249                   3.9     jackson-databind              2.9.7
# 250                   3.9     jackson-databind              2.9.7
#
# [251 rows x 9 columns]

# %% [markdown]
# ### Visualisierung
# Im folgenden Abschnitt wird mithilfe einiger Charts der Zusammenhang zwischen CVE, betroffenes Artefakt, Auftrittshäufigkeit und Schweregrade dargestellt.

# %%
df_count = df_compact['verwendetes Artefakt'].value_counts().to_frame()
df_count['Artefakt'] = df_count.index
df_count.columns =['Count CVE', 'Artefakt']
df_count.columns.name = None
df_count = df_count.reset_index()
df_count = df_count.loc[:,df_count.columns.isin(['Count CVE', 'Artefakt'])]
df_count
# Out:
#     Count CVE          Artefakt
# 0         139             mysql
# 1          34  jackson-databind
# 2          13           mongodb
# 3           8        postgresql
# 4           8            tomcat
# 5           7     elasticsearch
# 6           6          undertow
# 7           5          activemq
# 8           3        infinispan
# 9           3            jquery
# 10          3           mariadb
# 11          3             jetty
# 12          2            kotlin
# 13          2              java
# 14          2        httpclient
# 15          2              solr
# 16          2             netty
# 17          1             junit
# 18          1             dom4j
# 19          1            groovy
# 20          1          selenium
# 21          1         hibernate
# 22          1         hazelcast
# 23          1          htmlunit
# 24          1              bson
# 25          1             guava

# %%
pie_chart = pygal.Pie()
pie_chart.title = 'Artefakte mit Sicherheitsbedenken'
for i in range(len(df_count)):
    artefakt= df_count['Artefakt'][i]
    anzahl=df_count['Count CVE'][i]
    pie_chart.add(artefakt, anzahl)
display(HTML(base_html.format(rendered_chart=pie_chart.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2021-08-22--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0{background-color:rgba(249,249,249,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 path,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 line,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 rect,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .graph{fill:rgba(0,0,0,.87)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 text.no_data{fill:rgba(0,0,0,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .title{fill:rgba(0,0,0,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .axis .line{stroke:rgba(0,0,0,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .axis text.major{fill:rgba(0,0,0,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .axis.y .guides:hover .guide.line,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .line-graph .axis.x .guides:hover .guide.line,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .ci{stroke:rgba(0,0,0,.87)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .reactive.active,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .ci .reactive.active{stroke-width:1.5}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .series text{fill:rgba(0,0,0,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .tooltip .value{font-size:1.5em}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .bound{font-size:.5em}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .color-0,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .color-0 a:visited{stroke:#f44336;fill:#f44336}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .color-1,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .color-1 a:visited{stroke:#3f51b5;fill:#3f51b5}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .color-2,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .color-3,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .color-3 a:visited{stroke:#ffc107;fill:#ffc107}#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .color-4,#chart-fdf03086-2010-4bbf-a4a4-b1bce2bf50e0 .color-4 a:visit ...

# %%
top3 = df_count.head(3)

line_chart = pygal.Bar(show_legend=True, human_readable=True, fill=True, legend_at_bottom=True, print_values=True)

line_chart.title = 'Hohe Risiken bzgl. Top 3 der betroffenen Artefakte'
line_chart.x_labels = ['Confidentially risk', 'Integrity risk', 'Availability risks']

for j in top3.index:
    artefakt = top3['Artefakt'][j]
    df_interimResult = df_compact.loc[df_compact['verwendetes Artefakt'].str.contains(artefakt, case=False)]

    count_ci = len(df_interimResult[df_interimResult['Confidentially Impact'] == 'HIGH'])
    count_ii = len(df_interimResult[df_interimResult['Integrity Impact'] == 'HIGH'])
    count_ai = len(df_interimResult[df_interimResult['Availability Impact'] == 'HIGH'])
    line_chart.add(artefakt, [count_ci, count_ii, count_ai])

    

display(HTML(base_html.format(rendered_chart=line_chart.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-092d6300-f868-4c46-b038-543cc8432668" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2021-08-22--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-092d6300-f868-4c46-b038-543cc8432668{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-092d6300-f868-4c46-b038-543cc8432668 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-092d6300-f868-4c46-b038-543cc8432668 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-092d6300-f868-4c46-b038-543cc8432668 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-092d6300-f868-4c46-b038-543cc8432668 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-092d6300-f868-4c46-b038-543cc8432668 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-092d6300-f868-4c46-b038-543cc8432668 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-092d6300-f868-4c46-b038-543cc8432668{background-color:rgba(249,249,249,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 path,#chart-092d6300-f868-4c46-b038-543cc8432668 line,#chart-092d6300-f868-4c46-b038-543cc8432668 rect,#chart-092d6300-f868-4c46-b038-543cc8432668 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-092d6300-f868-4c46-b038-543cc8432668 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 .graph{fill:rgba(0,0,0,.87)}#chart-092d6300-f868-4c46-b038-543cc8432668 text.no_data{fill:rgba(0,0,0,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 .title{fill:rgba(0,0,0,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-092d6300-f868-4c46-b038-543cc8432668 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis .line{stroke:rgba(0,0,0,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis text.major{fill:rgba(0,0,0,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis.y .guides:hover .guide.line,#chart-092d6300-f868-4c46-b038-543cc8432668 .line-graph .axis.x .guides:hover .guide.line,#chart-092d6300-f868-4c46-b038-543cc8432668 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-092d6300-f868-4c46-b038-543cc8432668 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-092d6300-f868-4c46-b038-543cc8432668 .ci{stroke:rgba(0,0,0,.87)}#chart-092d6300-f868-4c46-b038-543cc8432668 .reactive.active,#chart-092d6300-f868-4c46-b038-543cc8432668 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-092d6300-f868-4c46-b038-543cc8432668 .ci .reactive.active{stroke-width:1.5}#chart-092d6300-f868-4c46-b038-543cc8432668 .series text{fill:rgba(0,0,0,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-092d6300-f868-4c46-b038-543cc8432668 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-092d6300-f868-4c46-b038-543cc8432668 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-092d6300-f868-4c46-b038-543cc8432668 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-092d6300-f868-4c46-b038-543cc8432668 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-092d6300-f868-4c46-b038-543cc8432668 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-092d6300-f868-4c46-b038-543cc8432668 .tooltip .value{font-size:1.5em}#chart-092d6300-f868-4c46-b038-543cc8432668 .bound{font-size:.5em}#chart-092d6300-f868-4c46-b038-543cc8432668 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-092d6300-f868-4c46-b038-543cc8432668 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-092d6300-f868-4c46-b038-543cc8432668 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-092d6300-f868-4c46-b038-543cc8432668 .color-0,#chart-092d6300-f868-4c46-b038-543cc8432668 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-092d6300-f868-4c46-b038-543cc8432668 .color-1,#chart-092d6300-f868-4c46-b038-543cc8432668 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-092d6300-f868-4c46-b038-543cc8432668 .color-2,#chart-092d6300-f868-4c46-b038-543cc8432668 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-092d6300-f868-4c46-b038-543cc8432668 .text-overlay .color-0 text{fill:black}#chart-092d6300-f868-4c46-b038-543cc8432668 .text-overlay .color-1 text{fill:black}#chart-092d6300-f868-4c46-b038-543cc8432668 .text-overlay .color-2 text{fill:black}
# #chart-092d6300-f868-4c46-b038-543cc8432668 text.no_data{text-anchor:middle}#chart-092d6300-f868-4c46-b038-543cc8432668 .guide.line{fill:none}#chart-092d6300-f868-4c46-b038-543cc8432668 .centered{text-anchor:middle}#chart-092d6300-f868-4c46-b038-543cc8432668 .title{text-anchor:middle}#chart-092d6300-f868-4c46-b038-543cc8432668 .legends .legend text{fill-opacity:1}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis.x text{text-anchor:middle}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis.y text{text-anchor:end}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis.y text[transform].backwards{text-anchor:start}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis.y2 text{text-anchor:start}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis.y2 text[transform].backwards{text-anchor:end}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis .guide.line{stroke-dasharray:4,4}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis .major.guide.line{stroke-dasharray:6,6}#chart-092d6300-f868-4c46-b038-543cc8432668 .horizontal .axis.y .guide.line,#chart-092d6300-f868-4c46-b038-543cc8432668 .horizontal .axis.y2 .guide.line,#chart-092d6300-f868-4c46-b038-543cc8432668 .vertical .axis.x .guide.line{opacity:0}#chart-092d6300-f868-4c46-b038-543cc8432668 .horizontal .axis.always_show .guide.line,#chart-092d6300-f868-4c46-b038-543cc8432668 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis.y .guides:hover .guide.line,#chart-092d6300-f868-4c46-b038-543cc8432668 .axis.y2 .guides:hover .guide.line,#chart-092d6300-f868-4c46-b038-543cc8432668 .axis.x .guides:hover .guide.line{opacity:1}#chart-092d6300-f868-4c46-b038-543cc8432668 .axis .guides:hover text{opacity:1}#chart-092d6300-f868-4c46-b038-543cc8432668 .nofill{fill:none}#chart-092d6300-f868-4c46-b038-543cc8432668 .subtle-fill{fill-opacity:.2}#chart-092d6300-f868-4c46-b038-

# %%
df_interimResult = df_compact[0:0]
TopRisk = top3['Artefakt'][0]
labels = ['Confidentially Impact', 'Integrity Impact', 'Availability Impact']
chartvalues = []

radar_chart = pygal.Radar()
radar_chart.title = 'Auswirkungen der Sicherheitslücken bei ' + TopRisk
radar_chart.x_labels = labels
radar_chart.y_labels = [
  {'label': 'High', 'value': 3},
  {'label': 'Medium', 'value': 2},
  {'label': 'Low', 'value': 1},
  {'label': 'None', 'value': 0}]

df_interimResult = df_compact.loc[df_compact['verwendetes Artefakt'].str.contains(TopRisk, case=False)]
df_interimResult = df_interimResult.drop_duplicates(subset='CVE-ID', keep="first")

for i in df_interimResult.index:
    cve_id = df_interimResult['CVE-ID'][i]
    c = 0
    for j in labels:
        if df_interimResult[j][i] == 'HIGH':
            df_interimResult[j][i] = 3
        elif df_interimResult[j][i] == 'MEDIUM':
            df_interimResult[j][i] = 2
        elif df_interimResult[j][i] == 'LOW':
            df_interimResult[j][i] = 1
        elif df_interimResult[j][i] == 'NONE':
            df_interimResult[j][i] = 0

    radar_chart.add(cve_id, [df_interimResult['Confidentially Impact'][i], df_interimResult['Integrity Impact'][i], df_interimResult['Integrity Impact'][i]])
    chartvalues.clear()
    

display(HTML(base_html.format(rendered_chart=radar_chart.render(is_unicode=True))))
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# c:\python37\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# c:\python37\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-165421f4-f83f-4ddb-a647-affdeee2ef7b" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2021-08-22--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-165421f4-f83f-4ddb-a647-affdeee2ef7b{background-color:rgba(249,249,249,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b path,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b line,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b rect,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .graph{fill:rgba(0,0,0,.87)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b text.no_data{fill:rgba(0,0,0,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .title{fill:rgba(0,0,0,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .legends .legend text{fill:rgba(0,0,0,.87)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .axis .line{stroke:rgba(0,0,0,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .axis text.major{fill:rgba(0,0,0,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .axis.y .guides:hover .guide.line,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .line-graph .axis.x .guides:hover .guide.line,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .stackedline-graph .axis.x .guides:hover .guide.line,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .ci{stroke:rgba(0,0,0,.87)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .reactive.active,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .ci .reactive.active{stroke-width:1.5}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .series text{fill:rgba(0,0,0,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .tooltip .value{font-size:1.5em}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .bound{font-size:.5em}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .color-0,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .color-0 a:visited{stroke:#f44336;fill:#f44336}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .color-1,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .color-1 a:visited{stroke:#3f51b5;fill:#3f51b5}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .color-2,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .color-2 a:visited{stroke:#009688;fill:#009688}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .color-3,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .color-3 a:visited{stroke:#ffc107;fill:#ffc107}#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .color-4,#chart-165421f4-f83f-4ddb-a647-affdeee2ef7b .color-4 a:visit ...

# %%
df_interimResult = df_compact[0:0]
cve_list = []

xy_chart = pygal.XY(stroke=False, x_title='Impact Score', y_title='Exploitability Score')
xy_chart.title = 'Score per CVE (Top3)'


for j in top3.index:
    artefakt = top3['Artefakt'][j]
    df_interimResult = df_compact.loc[df_compact['verwendetes Artefakt'].str.contains(artefakt, case=False)]
    
    for i in df_interimResult.index:
        cve_list.append({'value': (df_interimResult['Impact Score'][i], df_interimResult['Exploitability Score'][i]), 'label': df_interimResult['CVE-ID'][i]})
    
    xy_chart.add(artefakt, cve_list)
 

display(HTML(base_html.format(rendered_chart=xy_chart.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2021-08-22--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4{background-color:rgba(249,249,249,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 path,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 line,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 rect,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .graph{fill:rgba(0,0,0,.87)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 text.no_data{fill:rgba(0,0,0,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .title{fill:rgba(0,0,0,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis .line{stroke:rgba(0,0,0,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis text.major{fill:rgba(0,0,0,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis.y .guides:hover .guide.line,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .line-graph .axis.x .guides:hover .guide.line,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .ci{stroke:rgba(0,0,0,.87)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .reactive.active,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .ci .reactive.active{stroke-width:1.5}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .series text{fill:rgba(0,0,0,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .tooltip .value{font-size:1.5em}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .bound{font-size:.5em}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .color-0,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .color-1,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .color-2,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .text-overlay .color-0 text{fill:black}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .text-overlay .color-1 text{fill:black}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .text-overlay .color-2 text{fill:black}
# #chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 text.no_data{text-anchor:middle}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .guide.line{fill:none}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .centered{text-anchor:middle}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .title{text-anchor:middle}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .legends .legend text{fill-opacity:1}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis.x text{text-anchor:middle}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis.y text{text-anchor:end}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis.y text[transform].backwards{text-anchor:start}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis.y2 text{text-anchor:start}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis.y2 text[transform].backwards{text-anchor:end}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis .guide.line{stroke-dasharray:4,4}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis .major.guide.line{stroke-dasharray:6,6}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .horizontal .axis.y .guide.line,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .horizontal .axis.y2 .guide.line,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .vertical .axis.x .guide.line{opacity:0}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .horizontal .axis.always_show .guide.line,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis.y .guides:hover .guide.line,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis.y2 .guides:hover .guide.line,#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis.x .guides:hover .guide.line{opacity:1}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .axis .guides:hover text{opacity:1}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .nofill{fill:none}#chart-62b23d9b-617c-446d-9ac5-9d6b2bdc85e4 .subtle-fill{fill-opacity:.2}#chart-62b23d9b-617c-446d-9ac5-

# %%
df_interimResult = df_compact[0:0]
cveListC = []
cveListH = []
cveListM = []
cveListL = []
cveListN = []


treemap_ImpactS = pygal.Treemap()
treemap_ImpactS.title = 'Impact Score per CVE'

for j in df_count.index:
    artefakt = df_count['Artefakt'][j]
    df_interimResult = df_compact.loc[df_compact['verwendetes Artefakt'].str.contains(artefakt, case=False)]
    
    for i in df_interimResult.index:
        impactScore = df_interimResult['Impact Score'][i]
        if impactScore >= 9:
            cveListC.append({'value': df_interimResult['Impact Score'][i], 'label': (df_interimResult['CVE-ID'][i]+': ' + artefakt)})
        elif impactScore >= 7 and impactScore < 9:
            cveListH.append({'value': df_interimResult['Impact Score'][i], 'label': (df_interimResult['CVE-ID'][i]+': ' + artefakt)})
        elif impactScore >= 4 and impactScore < 7:
            cveListM.append({'value': df_interimResult['Impact Score'][i], 'label': (df_interimResult['CVE-ID'][i]+': ' + artefakt)})
        elif impactScore < 4:
            cveListL.append({'value': df_interimResult['Impact Score'][i], 'label': (df_interimResult['CVE-ID'][i]+': ' + artefakt)})
        elif impactScore == 0:
            cveListN.append({'value': df_interimResult['Impact Score'][i], 'label': (df_interimResult['CVE-ID'][i]+': ' + artefakt)})
    
treemap_ImpactS.add('Critical', cveListC)
treemap_ImpactS.add('High', cveListH)
treemap_ImpactS.add('Medium', cveListM)
treemap_ImpactS.add('Low', cveListL)
treemap_ImpactS.add('None', cveListN)
    
 

display(HTML(base_html.format(rendered_chart=treemap_ImpactS.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-0c49eaa3-b399-4a96-82cd-27d578d279c2" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2021-08-22--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-0c49eaa3-b399-4a96-82cd-27d578d279c2{background-color:rgba(249,249,249,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 path,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 line,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 rect,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .graph{fill:rgba(0,0,0,.87)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 text.no_data{fill:rgba(0,0,0,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .title{fill:rgba(0,0,0,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis .line{stroke:rgba(0,0,0,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis text.major{fill:rgba(0,0,0,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis.y .guides:hover .guide.line,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .line-graph .axis.x .guides:hover .guide.line,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .ci{stroke:rgba(0,0,0,.87)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .reactive.active,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .ci .reactive.active{stroke-width:1.5}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .series text{fill:rgba(0,0,0,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .tooltip .value{font-size:1.5em}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .bound{font-size:.5em}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .color-0,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .color-1,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .color-2,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .color-3,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .color-4,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .color-4 a:visit ...
# #chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 text.no_data{text-anchor:middle}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .guide.line{fill:none}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .centered{text-anchor:middle}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .title{text-anchor:middle}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .legends .legend text{fill-opacity:1}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis.x text{text-anchor:middle}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis.y text{text-anchor:end}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis.y text[transform].backwards{text-anchor:start}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis.y2 text{text-anchor:start}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis.y2 text[transform].backwards{text-anchor:end}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis .guide.line{stroke-dasharray:4,4}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .axis .major.guide.line{stroke-dasharray:6,6}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .horizontal .axis.y .guide.line,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .horizontal .axis.y2 .guide.line,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .vertical .axis.x .guide.line{opacity:0}#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .horizontal .axis.always_show .guide.line,#chart-0c49eaa3-b399-4a96-82cd-27d578d279c2 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-0c49eaa3-b399-4a96-82cd-27d57

# %%
df_interimResult = df_compact[0:0]
cveListC = []
cveListH = []
cveListM = []
cveListL = []
cveListN = []


treemap_ExploitS = pygal.Treemap()
treemap_ExploitS.title = 'Exploitability Score per CVE'

for j in df_count.index:
    artefakt = df_count['Artefakt'][j]
    df_interimResult = df_compact.loc[df_compact['verwendetes Artefakt'].str.contains(artefakt, case=False)]
    
    for i in df_interimResult.index:
        impactScore = df_interimResult['Exploitability Score'][i]
        if impactScore >= 9:
            cveListC.append({'value': df_interimResult['Exploitability Score'][i], 'label': (df_interimResult['CVE-ID'][i]+': ' + artefakt)})
        elif impactScore >= 7 and impactScore < 9:
            cveListH.append({'value': df_interimResult['Exploitability Score'][i], 'label': (df_interimResult['CVE-ID'][i]+': ' + artefakt)})
        elif impactScore >= 4 and impactScore < 7:
            cveListM.append({'value': df_interimResult['Exploitability Score'][i], 'label': (df_interimResult['CVE-ID'][i]+': ' + artefakt)})
        elif impactScore < 4:
            cveListL.append({'value': df_interimResult['Exploitability Score'][i], 'label': (df_interimResult['CVE-ID'][i]+': ' + artefakt)})
        elif impactScore == 0:
            cveListN.append({'value': df_interimResult['Exploitability Score'][i], 'label': (df_interimResult['CVE-ID'][i]+': ' + artefakt)})
    
treemap_ExploitS.add('Critical', cveListC)
treemap_ExploitS.add('High', cveListH)
treemap_ExploitS.add('Medium', cveListM)
treemap_ExploitS.add('Low', cveListL)
treemap_ExploitS.add('None', cveListN)
    
 

display(HTML(base_html.format(rendered_chart=treemap_ExploitS.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2021-08-22--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258{background-color:rgba(249,249,249,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 path,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 line,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 rect,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .graph{fill:rgba(0,0,0,.87)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 text.no_data{fill:rgba(0,0,0,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .title{fill:rgba(0,0,0,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis .line{stroke:rgba(0,0,0,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis text.major{fill:rgba(0,0,0,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis.y .guides:hover .guide.line,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .line-graph .axis.x .guides:hover .guide.line,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .ci{stroke:rgba(0,0,0,.87)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .reactive.active,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .ci .reactive.active{stroke-width:1.5}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .series text{fill:rgba(0,0,0,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .tooltip .value{font-size:1.5em}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .bound{font-size:.5em}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .color-0,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .color-1,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .color-2,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .color-3,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .color-4,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .color-4 a:visit ...
# #chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 text.no_data{text-anchor:middle}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .guide.line{fill:none}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .centered{text-anchor:middle}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .title{text-anchor:middle}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .legends .legend text{fill-opacity:1}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis.x text{text-anchor:middle}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis.y text{text-anchor:end}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis.y text[transform].backwards{text-anchor:start}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis.y2 text{text-anchor:start}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis.y2 text[transform].backwards{text-anchor:end}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis .guide.line{stroke-dasharray:4,4}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .axis .major.guide.line{stroke-dasharray:6,6}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .horizontal .axis.y .guide.line,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .horizontal .axis.y2 .guide.line,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .vertical .axis.x .guide.line{opacity:0}#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .horizontal .axis.always_show .guide.line,#chart-ed862c5d-15fc-46eb-bc44-d0238b9e5258 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-ed862c5d-15fc-46eb-bc44-d0238

# %% [markdown]
# ## Ergebnisse
# ### Softwareanalyse
# * Die häufigsten CVE bzgl. PEtclinic treten aufgrund von der Verwendung von mysql und FasterXML jackson-databind.
# * Besonders häufig werden Schwachstellen bzgl. der Verfügbarkeit ausgenutzt.
# * Einzeln werden zwar die Schweregrad bzgl. Verfügbarkeit, Integrität und Vertraulichkeit vorwiegend als 'High' eingestuft, allerdings wird dies nur bedingt durch den Impact Score und den Exploitability Score vermittelt. --> Wahrnehmung, dass die Risiken noch nicht kritisch "genug" sind.
#
# ### Hindernisse/Verbesserungspotentiale
# * Die betroffenen Artefaktversionen werden nicht in zwei Spalten gepflegt. Es wird stattdessen zwischen Startversion inklusive und exklusive und Endversion inklusive und exklusive unterschieden. Dies hat bis dato die weitere Eingrenzung der Liste verhindert, sodass eine manuelle zusätzliche Einkürzung noch notwendig ist.
# * Interessant wäre zudem auch eine Relation zwischen betroffene Artefakte, Klassen und Codezeilen. Bei dem Versuch dies über weitere Cypher-Anfragen und DataFrames darzustellen kam es zu keinem zufriedenenstellenden und plausiblen Ergebnis
# * Verbesserung der Schnittstelle zur API
# * Verbesserung der Regex-Ausdrücke

# %% [markdown]
# ## Nächste Schritte
# * Präsentation der Ergebnisse und Diskussion mit den Domainexperten und dem Projekt (womöglich einem Teil der Stakeholder)
# * Sichtung der Ergebnistabelle und weitere Kürzung der CVE-Liste
# * Planung & Aufwandsschätzung von möglichen Updates & Bugfixes
# * Regelmäßige CVE-Scans planen

# %% [markdown]
# ## Quellen
#
# - Software Analytics Canvas von Markus Harrer (https://www.feststelltaste.de/software-analytics-canvas/)
