# %% [markdown]
# # Preapering Running Project
# 1. Search/Find good Maven project and build it after download "mvn clean install" (cmd within project folder)
# 2.a) Start jqassistant with "mvn jqassistant:server" OR
# 2.b) Create dump --> Copy folder "store" into directory of single neo4j instance
# 3. "neo4j-admin dump --database="petclinic.db" --to="petclinic.dump"
# 4.1. for loading into single neo4j instance --> "neo4j-admin load --from="petclinic.dump" --database=petclinic --force"
# 4.2. "neo4j update-service" & "neo4j start" & "neo4j stop"
# 5. for loading into git project --> copy dump into neo4j folder

# %% [markdown]
# # To-Do's
# 1. Infos zur Business Canvas raussuchen & hier ergänzen
# 2. Infos zum Scannen anderer Projekte mit jqa raussuchen
# 3. Projekt aufräumen & unnötige Daten rauswerfen
# 4. zu scannenden Quellcode/Projekt raussuchen
# 4. Projekt bei git hochladen & mybinder einbinden

# %%
#Import of all importing libraries
import py2neo
import pandas as pd

import json
from pandas.io.json import json_normalize

import urllib3
from urllib3 import request
import json
import certifi

# %%
#Connecting to database in real time
# %reload_ext cypher
# %config CypherMagic.uri='http://neo4j:neo@localhost:7406/db/data'

# %%
#Connecting to database but saving it into a variable

graph = py2neo.Graph('http://neo4j:neo@localhost:7406/db/data')

# %%
#Saving data from a json into a DataFrame

df = pd.read_json('cve-item_example.json')
df
# Out:
#                  data_type data_format  data_version          CVE_data_meta  \
# ID                     CVE       MITRE             4          CVE-2020-8203
# ASSIGNER               CVE       MITRE             4  support@hackerone.com
# STATE                  CVE       MITRE             4                 PUBLIC
# vendor                 CVE       MITRE             4                    NaN
# problemtype_data       CVE       MITRE             4                    NaN
# reference_data         CVE       MITRE             4                    NaN
# description_data       CVE       MITRE             4                    NaN
#
#                                                             affects  \
# ID                                                              NaN
# ASSIGNER                                                        NaN
# STATE                                                           NaN
# vendor            {'vendor_data': [{'vendor_name': 'n/a', 'produ...
# ...

# %%
#Get all artifacts of project

query = """
MATCH (a:Artifact) 
RETURN a.fileName as FileName, a.fqn as fnq, a.type as Type
"""

artefactList = pd.DataFrame(graph.run(query), columns=['FileName', 'fnq', 'Type'])
artefactList
# Out:
#                                               FileName  \
# 0    C:/Users/jessi/.m2/repository/org/springframew...
# 1    C:/Users/jessi/.m2/repository/org/springframew...
# 2    C:/Users/jessi/.m2/repository/org/springframew...
# 3    C:/Users/jessi/.m2/repository/org/springframew...
# 4    C:/Users/jessi/.m2/repository/javax/annotation...
# ..                                                 ...
# 931  C:/Users/jessi/.m2/repository/org/infinispan/i...
# 932  C:/Users/jessi/.m2/repository/pl/project13/mav...
# 933  C:/Users/jessi/.m2/repository/org/eclipse/m2e/...
# 934  C:/Users/jessi/.m2/repository/org/jacoco/jacoc...
# 935  C:/Users/jessi/.m2/repository/ro/isdc/wro4j/wr...
#
#                                                    fnq      Type
# 0    org.springframework.samples:spring-petclinic:j...       jar
# 1    org.springframework.samples:spring-petclinic:t...  test-jar
# 2    org.springframework.boot:spring-boot-starter-l...       jar
# ...

# %%
#Get all artifacts, clean it from test-files & duplicates
#Clean up the versions of meaningsless parts for analysis

query2 = """
MATCH (artifact:Artifact) WHERE NOT artifact.name contains 'petclinic' AND NOT artifact.type = 'test-jar'
WITH DISTINCT artifact 
Return artifact.name as Framework, artifact.version as Frameworkversion
"""
fl = pd.DataFrame(graph.run(query2), columns=['Framework', 'Version'])
fl['Version'] = fl['Version'].str.replace('[.-]?[a-zA-Z]+[-]?\w+([.-]?\d*)*$','',regex=True)
fl
# Out:
#                                              Framework Version
# 0                          spring-boot-starter-logging   2.1.0
# 1                                  spring-boot-starter   2.1.0
# 2                                 javax.annotation-api   1.3.2
# 3                                          spring-core   5.1.2
# 4                                            snakeyaml    1.23
# ..                                                 ...     ...
# 929  infinispan-protocol-parser-generator-maven-plugin   9.4.0
# 930                               git-commit-id-plugin   2.2.5
# 931                                  lifecycle-mapping   1.0.0
# 932                                jacoco-maven-plugin   0.8.2
# 933                                 wro4j-maven-plugin   1.8.0
#
# [934 rows x 2 columns]

# %%
#another approach for reading a json

with open('cve-item_example.json') as json_data:
    data = json.load(json_data)

df = pd.DataFrame(data)
df
# Out:
#                  data_type data_format data_version          CVE_data_meta  \
# ID                     CVE       MITRE          4.0          CVE-2020-8203
# ASSIGNER               CVE       MITRE          4.0  support@hackerone.com
# STATE                  CVE       MITRE          4.0                 PUBLIC
# vendor                 CVE       MITRE          4.0                    NaN
# problemtype_data       CVE       MITRE          4.0                    NaN
# reference_data         CVE       MITRE          4.0                    NaN
# description_data       CVE       MITRE          4.0                    NaN
#
#                                                             affects  \
# ID                                                              NaN
# ASSIGNER                                                        NaN
# STATE                                                           NaN
# vendor            {'vendor_data': [{'vendor_name': 'n/a', 'produ...
# ...

# %%
#Getting data from a Circl-API & prepare it for analysis

http = urllib3.PoolManager(
    cert_reqs="CERT_REQUIRED",
    ca_certs=certifi.where()
)


url ='https://cve.circl.lu/api/cve/CVE-2020-24616'
#url ='https://cve.circl.lu/api/last'
r = http.request('GET', url)
r.status

# decode json data into a dict object
data = json.loads(r.data.decode('utf-8'))
#data

# in this dataset, the data to extract is under '...' --> to be decided
df = pd.json_normalize(data)

# %%
#Processing data from an CIRCL-API


#returns a list of true and false, which is used for selecting the columns of the dataframe
cList= df.columns.isin(['id', 'summary', 'impact.availability', 'impact.confidentiality', 'impact.integrity'])
#DataFrame with selected rows and columns
df2 = df.loc[:,cList]


vulnerabilities = pd.json_normalize(data, record_path='vulnerable_product', meta=['summary'])
vulnerabilities.columns =['vulnerable_product', 'summary']
vulnerabilities = vulnerabilities.loc[:,vulnerabilities.columns.isin(['vulnerable_product', 'summary'])]

#df2
#vulnerabilities

mergedList = pd.merge(left=df2, right=vulnerabilities, left_on='summary', right_on='summary')
mergedList
# Out:
#                 id                                            summary  \
# 0   CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# 1   CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# 2   CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# 3   CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# 4   CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# 5   CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# 6   CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# 7   CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# 8   CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# 9   CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# 10  CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# 11  CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
# ...

# %%
#Scanning the List for used frameworks and versions
#Loop with result in new Dictionary (because we need Key-Values)

terms = []

for j in fl.index:
    #print('Check of this Framework:'+ fl['Framework'][j])
    version = fl['Version'][j]
    framework = fl['Framework'][j]
    if version is not None:
        term = '(' + framework + '[^a-zA-Z_0-9]+' + version + ')'
        terms.append(term)
    else:
        terms.append('('+framework+')')
terms

mergedList[(mergedList['vulnerable_configuration'].str.contains('|'.join(terms)))]
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:17: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#                 id                                            summary  \
# 12  CVE-2020-24616  FasterXML jackson-databind 2.x before 2.9.10.6...
#
#    impact.availability impact.confidentiality impact.integrity  \
# 12             PARTIAL                PARTIAL          PARTIAL
#
#                              vulnerable_configuration
# 12  cpe:2.3:a:fasterxml:jackson-databind:2.9.7:*:*...

# %%
# load data using Python JSON module
with open('nvdcve-1.1-2021.json', encoding='utf-8') as staticData:
    jsonData = json.load(staticData)
df_nested_list = pd.json_normalize(jsonData, record_path =['CVE_Items'])
#df_nested_list

#returns a list of true and false, which is used for selecting the columns of the dataframe
vulnerableList= df_nested_list.columns.isin(['cve.CVE_data_meta.ID', 'impact.baseMetricV3.cvssV3.confidentialityImpact', 'impact.baseMetricV3.cvssV3.integrityImpact', 'impact.baseMetricV3.cvssV3.availabilityImpact'])
df_basic = df_nested_list.loc[:,vulnerableList]
df_basic.columns =['CVE-ID', 'Confidentially Impact', 'Integrity Impact', 'Availability Impact']
#df_basic

#new table with description value because value in a array "cve.description.description_data"
df_raw2 = df_nested_list.loc[:,df_nested_list.columns.isin(['cve.CVE_data_meta.ID', 'cve.description.description_data'])]

# reload & manipulation of DataFrame because of the dictionary within description_data
json_struct = json.loads(df_raw2.to_json(orient="records")) 
df_desc = pd.json_normalize(json_struct,record_path =['cve.description.description_data'], meta=['cve.CVE_data_meta.ID'])
df_desc = df_desc.loc[:,df_desc.columns.isin(['value', 'cve.CVE_data_meta.ID'])]
df_desc.columns =['CVE description', 'CVE-ID']

#joining of basic & description data
basicList = pd.merge(left=df_basic, right=df_desc, left_on='CVE-ID', right_on='CVE-ID')
basicList = basicList[['CVE-ID', 'CVE description', 'Confidentially Impact', 'Integrity Impact', 'Availability Impact']]
basicList
# Out:
#               CVE-ID                                    CVE description  \
# 0      CVE-2021-0001  Observable timing discrepancy in Intel(R) IPP ...
# 1      CVE-2021-0002  Improper conditions check in some Intel(R) Eth...
# 2      CVE-2021-0003  Improper conditions check in some Intel(R) Eth...
# 3      CVE-2021-0004  Improper buffer restrictions in the firmware o...
# 4      CVE-2021-0005  Uncaught exception in firmware for Intel(R) Et...
# ...              ...                                                ...
# 8889  CVE-2021-38708  In ocProducts Composr CMS before 10.0.38, an a...
# 8890  CVE-2021-38709  In ocProducts Composr CMS before 10.0.38, an a...
# 8891  CVE-2021-38711  In gitit before 0.15.0.0, the Export feature c...
# 8892  CVE-2021-38712  OneNav 0.9.12 allows Information Disclosure of...
# 8893  CVE-2021-38713  imgURL 2.31 allows XSS via an X-Forwarded-For ...
#
#      Confidentially Impact Integrity Impact Availability Impact
# ...

# %%
#new table with description value because value in a dictionary "configurations.nodes"
newList= df_nested_list.columns.isin(['cve.CVE_data_meta.ID', 'configurations.nodes'])
df_raw3 = df_nested_list.loc[:,newList]

# reload & manipulation of DataFrame because of the dictionary within configurations.nodes
json_struct = json.loads(df_raw3.to_json(orient="records")) 
df_conf = pd.json_normalize(json_struct,record_path =['configurations.nodes'], meta=['cve.CVE_data_meta.ID'])
json_struct = json.loads(df_conf.to_json(orient="records")) 
df_conf2 = pd.json_normalize(json_struct,record_path =['cpe_match'], meta=['operator', 'cve.CVE_data_meta.ID'])

#Cutting & changing names of columns
df_conf2 = df_conf2.loc[:,df_conf2.columns.isin(['vulnerable', 'cpe23Uri', 'versionEndIncluding', 'versionEndExcluding', 'versionStartIncluding', 'versionStartExcluding', 'operator', 'cve.CVE_data_meta.ID'])]
df_conf2.columns =['Vulnerable for system?', 'cpe23URI', 'Last version (incl)', 'Last version (excl)', 'First version (incl)', 'First version (excl)', 'Connector/Relation', 'CVE-ID']
df_conf2 = df_conf2[['CVE-ID', 'Vulnerable for system?', 'Connector/Relation', 'cpe23URI', 'Last version (incl)', 'Last version (excl)', 'First version (incl)', 'First version (excl)']]
df_conf2
# Out:
#                CVE-ID  Vulnerable for system? Connector/Relation  \
# 0       CVE-2021-0001                    True                 OR
# 1       CVE-2021-0001                    True                 OR
# 2       CVE-2021-0001                    True                 OR
# 3       CVE-2021-0001                    True                 OR
# 4       CVE-2021-0001                    True                 OR
# ...               ...                     ...                ...
# 37172  CVE-2021-38572                    True                 OR
# 37173  CVE-2021-38573                    True                 OR
# 37174  CVE-2021-38573                    True                 OR
# 37175  CVE-2021-38574                    True                 OR
# 37176  CVE-2021-38574                    True                 OR
#
#                                                 cpe23URI Last version (incl)  \
# 0      cpe:2.3:a:intel:integrated_performance_primiti...                 NaN
# ...

# %%
#df_desc
#df_basic
#df_conf2
basicList
# Out:
#               CVE-ID                                    CVE description  \
# 0      CVE-2021-0001  Observable timing discrepancy in Intel(R) IPP ...
# 1      CVE-2021-0002  Improper conditions check in some Intel(R) Eth...
# 2      CVE-2021-0003  Improper conditions check in some Intel(R) Eth...
# 3      CVE-2021-0004  Improper buffer restrictions in the firmware o...
# 4      CVE-2021-0005  Uncaught exception in firmware for Intel(R) Et...
# ...              ...                                                ...
# 8889  CVE-2021-38708  In ocProducts Composr CMS before 10.0.38, an a...
# 8890  CVE-2021-38709  In ocProducts Composr CMS before 10.0.38, an a...
# 8891  CVE-2021-38711  In gitit before 0.15.0.0, the Export feature c...
# 8892  CVE-2021-38712  OneNav 0.9.12 allows Information Disclosure of...
# 8893  CVE-2021-38713  imgURL 2.31 allows XSS via an X-Forwarded-For ...
#
#      Confidentially Impact Integrity Impact Availability Impact
# ...

# %% [markdown]
# # Infos CVE
# CVE = Common Vulnerabilities and Exposures
# * Industriestandard zur Benennung öffentlich bekannter Sicherheitslücken
# * gewissen Druck auf die Hersteller der betroffenen Produkte aufgrund öffentlicher Schwachstellen
# * in großen Teilen ein Community-Projekt --> Kopf ist die MITRE Organization

# %% [markdown]
# # Software-Analyse hinsichtlich eines möglichen CVE-Checks

# %% [markdown]
# ## Fragestellung

# %% [markdown]
# ### <center>Was möchte ich über die zu analysierende Software, Prozesse, Verwendung, Organisation etc. wissen?</center>
#
# - **Starte mit einer relevanten Frage!** --> Treten in dem vorliegenden Git-Projekt Sicherheitslücken über veralteten oder lückenhafte Bibliotheken auf? Welche sind es bzw. nutzt die Software genau die risikoreiche Bibliotheken auf die ich checke?
# - **Reales Problem?** Historische Systeme haben die Tendenz veraltete Libs zu nutzen! Check ist notwendigen für zum Beispiel ISO-Zertifizierungen, Schutz von hypersensiblen Daten (man denke an das Bankenumfeld und Authentifizierungssysteme, die eingebunden werden!)
# - **Für wen relevant?** KUNDEN first of all(indirekt)! Es sind ihre Daten, die den Sicherheitslücken und den Risiken, Angriffen ausgesetzt sind --> üben Druck auf Provider aus --> also darf die Ignoranz/Faulheit keine Rolle für Dienstleister spielen --> Software Analytics + Visualisierung der bestehenden Lücken mit minimalen Aufwand ist attraktiv (besser als z.b Kopie der verwendeten Listen und Gegencheck mit CVE-Liste bzw. ggf Entwicklung eines eigenes Checktools)
# - **Was ändern die Analyseergebnisse?**
# -- Dienstleister --> weiterführende Analyse/Bewertung: welche Libs sind für uns relevant? Welche müssen priorisiert werden? Wann können/müssen sie aktualisiert werden? (Wann spätestens?) Was können wir machen,falls es noch keinen Fix gibt? Aufwandschätzung in der Entwicklung bzgl. Aktualisierung, Test, Integration, Auslieferung? Planung für Inkludierung in neues Release, Light-Release, Snapshot, Hotfix/Bugfix?
# -- Kunden --> Druck bei Dienstleister, Worst-Case Anbieterwechsel
#
# Every decent analysis starts with a good/interesting/relevant question. So in the first section, you can state your very specific question. What do you intend to analyze? Is it a question about a real problem? Or are you talking only about a symptom? Also: Who cares about the issue and will listen to your (probably unpleasant) answers? And most importantly: If you have the result, what would it change based on the new insights?

# %% [markdown]
# ## Datenquelle

# %% [markdown]
# ### <center>Welche Daten können womöglich unsere Frage beantworten? Welche Informationen brauchen wir?</center>
#
# - Welche Daten kann ich organisieren? Projekt mit Bytecode mit verschiedenen Artefakten, jqassistent beim Mavenbuild-Prozess laufen lassen --> Load & Dump über neo4j-Instanz, verfügbare CVE's importieren entweder manuell oder über API
# - Welche Informationen kann ich aus diesen Daten ziehen? Frameworks und Versionsnummer --> auch Zusammenhänge zwischen den Frameworks
# - Welche Daten fehlen möglicherweise? Es gibt Frameworks ohne Versionsnummer, Versionsnummer mit "Verunreinheiten"
# - Benötige ich zusätzliche Datensammlungen über den Umfang heraus?
#
# **Die Datenwahl von Anfang an ist äußerst wichtig um spätere *falsche* Schlußfolgerungen zu vermeiden! Falls du Daten von einem System extrahieren musst, dann clarify wie die Daten exportiert hast!**

# %% [markdown]
# ## Annahmen

# %% [markdown]
# ### <center>Welche Annahmen wollen wir machen um die Antwort auf unsere Frage zu vereinfachen?</center>
#
# Nicht alle Daten aus dem existierenden System sind gute Kandidaten für eine Softwareanalyse. Darüberhinaus können wir nicht annehmen, dass wir Daten habe, die unsere Frage genaustens beantworten kann.
#
# - Welche Approcimationen aufgrund der Daten **können** wir machen?
# - Was siehst du in den Daten?
# - Dokumentiere deine Simplification bzgl. der Datenpunkte!

# %% [markdown]
# ## Validierung

# %% [markdown]
# ### <center>Welche Ergebnisse erwarten wir von der Analyse?</center>
# ### <center>Wie werden diese Ergebnisse verständlich reviewed und präsentiert?</center>
#
# Der Schlüssel um einen wirklichen Unterschied zu bevor mit Softwareanalyse zu erzielen ist es, die Analyse verständlich und comprehensively für die Leute zu präsentieren, die als Entscheidungsträger fungieren oder Geld dafür ausgeben --> Stakeholder!
#
# - Wie können die Resultate für Stakeholder aufbereitet werden? Welche Frameworks, die WIR benutzen weisen Sicherheitslücken auf? Welche KLassen, Funktionen betreffen sie? Sind es häufige Klassen/Fkt?
# - Wenn wir eine Antwort auf unsere zentrale Frage haben --> Wohin wollen wir arbeiten um zu den grundlegenden Problem zu kommen?

# %% [markdown]
# ## Implementierung

# %% [markdown]
# ### <center>Wie können wir die Analyse schrittweise verständlich implementieren?</center>
#
# Denk vorher über den Code nach! Was willst du implementieren? Was kannst du vereinfachen? Zu kompliziert und niemand versteht ihn. --> Leute werden an den Resultaten zweifeln.
#
# - Zeichne zuerst mögliche grobe Implementierungsvarianten ab
# - Welche Tools willst du verwenden?
#
# Verlier dich nicht im Analysecode!

# %% [markdown]
# ## Ergebnisse

# %% [markdown]
# ### <center>Was sind die hauptsächlichen Insight resultierend der Analyse?</center>
#
# - Liste Key Point aus der Analyse auf!
# - Was sind die aktionswürdigen Insights, die du gefunden hast?
# - - Selbst wenn es keine gibt --> dokumentiere!
# - - Hat die Analyse nicht wie gedacht funktioniert?
# - - Sind deine Ergebnisse nicht gut belegbar, Beweise zu schwach?
#
# Dokumentiere alles, denn Erfahrung ist Erfahrung!

# %% [markdown]
# ## Nächste Schritte

# %% [markdown]
# ### <center>Welche Folgeaktionen können wir aus den Ergebnissen ziehen?</center>
# ### <center>Wer oder was muss als nächstes addressiert werden?</center>
#
# Software-Analyse ist nicht komplett, wenn die nächsten Schritte fehlen, welche die Situation verbessern soll!
#
# - Welche Entscheidungen können die Ergebnisse supporten oder zu einem ad absurdum führen?
# - Welche Experimente können anhand der Ergebnisse/Fakten jetzt ausgeführt werden?
# - Schreibe eine To-Do-Liste oder Ideen für eine weiterführende Analyse um die bestehenden neuen Insights tiefer zu ergründen!

# %% [markdown]
# ## Quellen
#
# - Software Analytics Canvas von Markus Harrer (https://www.feststelltaste.de/software-analytics-canvas/)
